# %% [markdown]
# # Removing Empty Tuple(s) from List

# %%
L = [(), (), ('',), ('a', 'b'), (), ('a', 'b', 'c'), (), ('d',)]

# Remove empty tuples
L = [t for t in L if t]

print("Result =", L)
# Out:
# Result = [('',), ('a', 'b'), ('a', 'b', 'c'), ('d',)]
